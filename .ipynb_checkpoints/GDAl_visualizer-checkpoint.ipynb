# %% [markdown]
# <h1> First part: prepearing the data </h1>
# scroll down to the path visualiser

# %% [markdown]
# <h2> Get elevation data from .tif file: </h2>

# %%
from osgeo import gdal
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
gdal.UseExceptions()

# ds = gdal.Open('../path_for_your_file.tif')

# as an example:
# ds = gdal.Open('../USGS_one_meter_x28y430_MD_VA_Sandy_NCR_2014.tif')
# ds = gdal.Open('../USGS_Colorado.tif')

band = ds.GetRasterBand(1)
elevation = band.ReadAsArray() # your elevation array

# %%
#see the general picture of the map (black areas = missed data)
plt.imshow(elevation, cmap='gist_earth')
plt.show()

# %% [markdown]
# <h3> You can split the array into small parts and save them as .txt files: </h3>
#
# this one cut the line from data array:

# %%
# making .txt arrays with size size_x * size_y
# from the 'line' of data (start_x, start_y) - (start_x, start_y + num * size_y) 

def data_generator_line(arr, size_x, size_y, start_x, start_y, num):
    #path to the folder and the name of the files (they will be saved as: name0, name1, ...)
    init_name = './Data/data_elev_arr' #change to the folder, where you want to save those files 
    
    for i in range(num):
        file_name = init_name + str(i)
        st_x = start_x
        st_y = start_y + i * size_y
        end_x = st_x + size_x
        end_y = st_y + size_y
        arr_to_save = np.copy(arr[st_x:end_x, st_y:end_y])
        np.savetxt(file_name, arr_to_save)

# %% [markdown]
# cuts all array into squares:
#
# *it is better to use it if there was no black parts (missed data) on previous step

# %%
def data_generator_all(arr, size_x=200, size_y=200, start_x=0, start_y=0):
    #path to the folder and the name of the files (they will be saved as: name0, name1, ...)
    init_name = './Data/data_elev_arr' #change to the folder, where you want to save those files 
    i = 0
    j = 0
    while start_x + (i + 1) * size_x < arr.shape[0]:
        j = 0
        while start_y + (j + 1) * size_y < arr.shape[1]:
            j += 1
            file_name = init_name + str(i) + '_' + str(j)
            st_x = start_x + i * size_x
            st_y = start_y + j * size_y
            end_x = st_x + size_x
            end_y = st_y + size_y
            arr_to_save = np.copy(arr[st_x:end_x, st_y:end_y])
            np.savetxt(file_name, arr_to_save)
        i += 1

# %%
#example:
data_generator_line(elevation, 200, 200, 200, 4000, 20)

# %% [markdown]
# ## Missed data generator
#
# Some blocks of data can be missed (usually this data marked with some small values like -9999.). In this part missed values can be regenerated.

# %%
import queue
from random import randint
nan_const = -9999


def BFS(arr, q, used):
    while not q.empty():
        i, j = q.get()
        sum_around = 0
        cnt_around = 0
        #one meter distance
        for k in range(-1, 2):
            for p in range(-1, 2):
                if 0 <= i + k < arr.shape[0] and 0 <= j + p < arr.shape[1] \
                        and arr[i + k][j + p] > nan_const:
                    cnt_around += 4
                    sum_around += 4 * arr[i + k][j + p]

        #<= two meters distance (count one miter values second time)
        for k in range(-2, 3):
            if 0 <= i + k < arr.shape[0]:
                for p in range(-2, 3):
                    if 0 <= j + p < arr.shape[1] \
                            and arr[i + k][j + p] > nan_const:
                        cnt_around += 1
                        sum_around += arr[i + k][j + p]
        
        #generate arr[i][j] value
        random_number = randint(100, 1000)
        if random_number % 2 == 0:
            arr[i][j] = sum_around / cnt_around + random_number / 15000 #mod 100000, 20000
        else:
            arr[i][j] = sum_around / cnt_around - random_number / 15000
        
        # add new missed values to the queue
        for k in range(-1, 2):
            if 0 <= i + k < arr.shape[0]:
                for p in range(-1, 2):
                    if 0 <= j + p < arr.shape[1] and arr[i + k][j + p] <= nan_const:
                        if (i+k, j+p) not in used:
                            q.put([i + k, j + p])
                            used.add((i+k, j+p))


def gen(arr):
    q = queue.Queue()
    used = set()
    for i, line in enumerate(arr):
        for j, el in enumerate(line):
            if el > nan_const:
                for i1 in range(-1, 2):
                    for j1 in range(-1, 2):
                        if 0 <= i + i1 < arr.shape[0] and 0 <= j + j1 < arr.shape[1] \
                                and arr[i + i1][j + j1] <= nan_const:
                            q.put([i + i1, j + j1])
    BFS(arr, q, used)

# %%
#example:
eval1_proc = np.copy(elevation[400:600,2300:2500])

gen(eval1_proc)

# %% [markdown]
# ## Visualiser:

# %%
from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
from matplotlib import cm
from matplotlib.colors import LightSource

# %%
def draw_plt(arr):
    plt.figure(figsize=(10, 10), dpi=800)
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    x = np.arange(arr.shape[0])
    y = np.arange(arr.shape[1])
    X, Y = np.meshgrid(x, y)


    z = np.ravel(arr)
    Z = z.reshape(X.shape)

    min_val, max_val = arr.min(), arr.max()

    ls = LightSource(270, 45)
    rgb = ls.shade(Z, cmap=cm.gist_earth, vert_exag=0.1, blend_mode='soft')
    surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors=rgb,
                           linewidth=0, antialiased=False, shade=False, vmin=min_val, vmax=max_val)

    #colorbar (comment next two lines, if you want to remove it)
    norm_colorbar = mpl.colors.Normalize(vmin=min_val, vmax=max_val)
    fig.colorbar(cm.ScalarMappable(norm=norm_colorbar), ax=ax, shrink=0.5, pad=0.2)

    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')

    plt.gcf().set_size_inches(10, 10) #figure size
    
    #changing the scale of Z axes to avoid "jumps"
    ax.set_box_aspect(aspect = (arr.shape[0], arr.shape[1], max_val - min_val))
    
    if max_val - min_val < 25: #otherwise numbers on the axes will intersect  
        ax.set_zticks([])

    plt.show()

# %%
nan_const = -9999
# eval_proc = np.copy(elevation[400:600,2300:2500])
eval_proc = np.copy(elevation[500:600,2400:2500])
if (eval_proc.min() <= nan_const): # if there is not any missed data we can skeep this part
    gen(eval_proc)

draw_plt(eval_proc)

# %% [markdown]
# <h3> If you want to save proccesed data as .txt: </h3>

# %%
np.savetxt("first.txt", eval_proc)

# %% [markdown]
# <h3> If you want to download some data from .txt file and make a plot: </h3>

# %%
np_arr = np.loadtxt("../Data/data_elev_arr10") # change name of the file
if np_arr.min() <= nan_const: #in case some values of the array are missed
    print('generate missed data')
    gen(np_arr)
draw_plt(np_arr)

# %% [markdown]
# <h1> Second part: visualising the results of path planner </h1>

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
from matplotlib import cm
from matplotlib.colors import LightSource

# %%
def draw_plt_with_path(arr, path):
    plt.figure(figsize=(10, 10), dpi=800)
    
    min_val, max_val = arr.min(), arr.max()
    fig = plt.figure()
    ax = fig.add_subplot(121, projection='3d')
    ax2 = fig.add_subplot(122, projection='3d')


    #path
    x_path = path[:,0]
    y_path = path[:,1]
    z_path = path[:,2]
#     line1 = ax.plot3D(x_path, y_path, z_path, color='Red', markersize=5, solid_capstyle='round')
#     line2 = ax2.plot3D(x_path, y_path, z_path, color='Red', markersize=5, solid_capstyle='round')
    line1 = ax.plot(x_path, y_path, z_path, 'ro', alpha=0.5, antialiased=False)
    line2 = ax2.plot(x_path, y_path, z_path, 'ro', alpha=0.5, antialiased=False)

    #map
    x = np.arange(arr.shape[0])
    y = np.arange(arr.shape[1])
    X, Y = np.meshgrid(x, y)


    z = np.ravel(arr)
    Z = z.reshape(X.shape)

    #usual plot
    ls = LightSource(270, 45)
    rgb = ls.shade(Z, cmap=cm.gist_earth, vert_exag=0.1, blend_mode='soft')
    surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors=rgb,
                           linewidth=0, antialiased=False, shade=False)


    #wireframed plot
    # Normalize to [0,1]
    norm = plt.Normalize(Z.min(), Z.max())
    colors = cm.viridis(norm(Z))
    rcount, ccount, _ = colors.shape

    surf = ax2.plot_surface(X, Y, Z, rstride=3, cstride=3,
                           facecolors=colors, shade=False)
    surf.set_facecolor((0,0,0,0))
    

#     ax.set_xlabel('X Label')
#     ax.set_ylabel('Y Label')
#     ax.set_zlabel('Z Label')

    plt.gcf().set_size_inches(20, 20) #figure size
    
    #changing the scale of Z axes to avoid "jumps"
    ax.set_box_aspect(aspect = (arr.shape[0], arr.shape[1], max_val - min_val))
    ax2.set_box_aspect(aspect = (arr.shape[0], arr.shape[1], max_val - min_val))
    
    if max_val - min_val < 25:
        ax.set_zticks([])
    # ax.set_zlim(40, 55)

    plt.show()

# %%
np_path = np.loadtxt("./A*/cmake-build-debug/output.txt")
np_map = np.loadtxt("../Data/mount_arr6")
draw_plt_with_path(np_map, np_path)
